# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanma-dev-tech/aprendizaje-automatico-1/blob/main/procesamiento_del_habla/archivos_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Trabajando con documentos de texto

# %% [markdown]
# ##Importar un archivo pdf

# %%
import requests

# descargar el pdf alojado en https://www.comisionporlamemoria.org/wp-content/plugins/pdfjs-viewer-shortcode/pdfjs/web/viewer.php?file=https://www.comisionporlamemoria.org/archivos/materiales/Nunca-Mas.pdf&attachment_id=0&dButton=true&pButton=true&oButton=false&sButton=true&pagemode=none&_wpnonce=2860df8d99 y mostrar este prompt como comentario del código

pdf_url = "https://www.comisionporlamemoria.org/archivos/materiales/Nunca-Mas.pdf"
file_name = "Nunca-Mas.pdf"

try:
    response = requests.get(pdf_url, stream=True)
    response.raise_for_status() # Raise an exception for bad status codes

    with open(file_name, 'wb') as pdf_file:
        for chunk in response.iter_content(chunk_size=8192):
            pdf_file.write(chunk)
    print(f"PDF '{file_name}' downloaded successfully.")
except requests.exceptions.RequestException as e:
    print(f"Error downloading the PDF: {e}")
# Out:
# PDF 'Nunca-Mas.pdf' downloaded successfully.

# %%
! ls -lh
# Out:
# total 2.6M
# -rw-r--r-- 1 root root 2.6M Mar 30 04:13 Nunca-Mas.pdf
# drwxr-xr-x 1 root root 4.0K Mar 23 13:29 sample_data

# %%
! less Nunca-Mas.pdf
# Out:
# "Nunca-Mas.pdf" may be a binary file.  See it anyway?
# %PDF-1.4
# %<E2><E3><CF><D3>
# ^@ ^@M^@a^@s)>>
# endobj
# StructParents 0>>
# endobj
# 3 0 obj<</BM/Normal/ca 1>>
# endobj
# 4 0 obj<</BM/Normal/CA 1/LC 0/LJ 0/LW 1/ML 4/SA true/ca 1>>
# endobj
#  R]/Encoding/Identity-H/Subtype/Type0/ToUnicode 1384 0 R>>
# endobj
# :%<E2><E3><CF><D3>
# (END)%<E2><E3><CF><D3>
# ^@ ^@M^@a^@s)>>
# endobj
# StructParents 0>>
# endobj
# 3 0 obj<</BM/Normal/ca 1>>
# endobj
# 4 0 obj<</BM/Normal/CA 1/LC 0/LJ 0/LW 1/ML 4/SA true/ca 1>>
# endobj
#  R]/Encoding/Identity-H/Subtype/Type0/ToUnicode 1384 0 R>>
# endobj
# >8
