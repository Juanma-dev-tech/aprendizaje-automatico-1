# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanma-dev-tech/aprendizaje-automatico-1/blob/main/UNIDAD_1_carga_dataset_ejemplos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Carga de datasets

# %%
url = "https://archive.ics.uci.edu/static/public/484/travel+reviews.zip"

# %%
! wget https://archive.ics.uci.edu/static/public/484/travel+reviews.zip
# Out:
# --2026-03-30 03:22:07--  https://archive.ics.uci.edu/static/public/484/travel+reviews.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘travel+reviews.zip’
#
# travel+reviews.zip      [ <=>                ]  56.10K  --.-KB/s    in 0.1s
#
# 2026-03-30 03:22:08 (439 KB/s) - ‘travel+reviews.zip’ saved [57449]

# %%
# !ls
# Out:
# sample_data  travel+reviews.zip

# %%
! unzip travel+reviews.zip
# Out:
# Archive:  travel+reviews.zip
#  extracting: tripadvisor_review.csv

# %%
! ls
# Out:
# sample_data  travel+reviews.zip  tripadvisor_review.csv

# %%
# prompt: cargar el archivo csv extraído, por favor agregar este prompt como comentario al código
import pandas as pd
df = pd.read_csv('tripadvisor_review.csv')
print(df.head())
# Out:
#   User ID  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 0  User 1        0.93         1.8        2.29        0.62        0.80
# 1  User 2        1.02         2.2        2.66        0.64        1.42
# 2  User 3        1.22         0.8        0.54        0.53        0.24
# 3  User 4        0.45         1.8        0.29        0.57        0.46
# 4  User 5        0.51         1.2        1.18        0.57        1.54
#
#    Category 6  Category 7  Category 8  Category 9  Category 10
# 0        2.42        3.19        2.79        1.82         2.42
# 1        3.18        3.21        2.63        1.86         2.32
# 2        1.54        3.18        2.80        1.31         2.50
# 3        1.52        3.18        2.96        1.57         2.86
# 4        2.02        3.18        2.78        1.18         2.54

# %%
#prompt: resumen de los principales indicadores estadísticos del dataframe
print(df.describe())
# Out:
#        Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# count  980.000000  980.000000  980.000000  980.000000  980.000000  980.000000
# mean     0.893194    1.352612    1.013306    0.532500    0.939735    1.842898
# std      0.326912    0.478280    0.788607    0.279731    0.437430    0.539538
# min      0.340000    0.000000    0.130000    0.150000    0.060000    0.140000
# 25%      0.670000    1.080000    0.270000    0.410000    0.640000    1.460000
# 50%      0.830000    1.280000    0.820000    0.500000    0.900000    1.800000
# 75%      1.020000    1.560000    1.572500    0.580000    1.200000    2.200000
# max      3.220000    3.640000    3.620000    3.440000    3.300000    3.760000
#
#        Category 7  Category 8  Category 9  Category 10
# count  980.000000  980.000000  980.000000   980.000000
# mean     3.180939    2.835061    1.569439     2.799224
# std      0.007824    0.137505    0.364629     0.321380
# ...

# %%
df.shape
# Out:
# (980, 11)

# %% [markdown]
# #Dataset de análisis de *sentimiento*

# %%
# descargar el zip desde https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip, descomprimirlo, cargar en variable dataset el archivo csv agregar el prompt al codigo como comentario
# !wget https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip
# !unzip sentiment+labelled+sentences.zip

import pandas as pd

# The unzipped file often contains a folder or multiple files. Let's check common names.
# This particular dataset provides three text files within a 'sentiment labelled sentences' directory:
# 'amazon_cells_labelled.txt', 'imdb_labelled.txt', 'yelp_labelled.txt'.
# These are typically tab-separated values, not comma-separated (CSV).
# I will load the 'amazon_cells_labelled.txt' as an example into the 'dataset' variable.

# List files to confirm structure after unzipping
# !ls -F "sentiment labelled sentences/"

# Load 'amazon_cells_labelled.txt' (tab-separated) into the 'dataset' variable
dataset = pd.read_csv('sentiment labelled sentences/amazon_cells_labelled.txt', sep='\t', header=None, names=['sentence', 'sentiment'])

print(dataset.head())
# Out:
# --2026-03-30 03:46:20--  https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘sentiment+labelled+sentences.zip’
#
# sentiment+labelled+     [ <=>                ]  82.21K  --.-KB/s    in 0.1s
#
# 2026-03-30 03:46:20 (619 KB/s) - ‘sentiment+labelled+sentences.zip’ saved [84188]
#
# Archive:  sentiment+labelled+sentences.zip
#    creating: sentiment labelled sentences/
#   inflating: sentiment labelled sentences/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/sentiment labelled sentences/
#   inflating: __MACOSX/sentiment labelled sentences/._.DS_Store
#   inflating: sentiment labelled sentences/amazon_cells_labelled.txt
#   inflating: sentiment labelled sentences/imdb_labelled.txt
# ...

# %%
! head amazon_cells_labelled.txt
# Out:
# head: cannot open 'amazon_cells_labelled.txt' for reading: No such file or directory

# %%
import pandas as pd

dataset = pd.read_csv('/content/sentiment labelled sentences/amazon_cells_labelled.txt', sep='\t', header=None, names=['sentence', 'sentiment'])
print(dataset.head())
# Out:
#                                             sentence  sentiment
# 0  So there is no way for me to plug it in here i...          0
# 1                        Good case, Excellent value.          1
# 2                             Great for the jawbone.          1
# 3  Tied to charger for conversations lasting more...          0
# 4                                  The mic is great.          1

# %%
dataset.describe()
# Out:
#         sentiment
# count  1000.00000
# mean      0.50000
# std       0.50025
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %%
dataset.shape
# Out:
# (1000, 2)
